# %% [markdown]
# # Compare NLP Techniques: Build Model On TF-IDF Vectors

# %% [markdown]
# ### Read In Cleaned Text

# %%
# Load the cleaned training and test sets
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

X_train = pd.read_csv('../../../data/X_train.csv')
X_test = pd.read_csv('../../../data/X_test.csv')
y_train = pd.read_csv('../../../data/y_train.csv')
y_test = pd.read_csv('../../../data/y_test.csv')

X_train.head()
# Out:
#                                           clean_text
# 0  ['hello', 'love', 'get', 'interview', 'today',...
# 1                    ['know', 'pls', 'open', 'back']
# 2  ['case', 'wake', 'wondering', 'forgot', 'take'...
# 3  ['gran', 'onlyfound', 'afew', 'days', 'agocuso...
# 4  ['please', 'call', 'customer', 'service', 'rep...

# %% [markdown]
# ### Create TF-IDF Vectors

# %%
# Instantiate and fit a TFIDF vectorizer and then use that trained vectorizer
# to transform the messages in the training and test sets
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(X_train['clean_text'])
X_train_vect = tfidf_vect.transform(X_train['clean_text'])
X_test_vect = tfidf_vect.transform(X_test['clean_text'])

# %%
# What words did the vectorizer learn?
tfidf_vect.vocabulary_
# Out:
# {'hello': 3584,
#  'love': 4488,
#  'get': 3296,
#  'interview': 3934,
#  'today': 7326,
#  'happy': 3528,
#  'good': 3364,
#  'boy': 1575,
#  'think': 7235,
#  'meare': 4689,
#  'missing': 4808,
#  'know': 4218,
#  'pls': 5597,
#  'open': 5286,
#  'back': 1291,
#  'case': 1797,
#  'wake': 7760,
#  'wondering': 7987,
#  'forgot': 3125,
#  'take': 7076,
#  'care': 1773,
#  'something': 6673,
#  'grandma': 3411,
#  'done': 2565,
#  'parade': 5403,
#  'gran': 3408,
#  'onlyfound': 5279,
#  'afew': 918,
#  'days': 2332,
#  'agocusoon': 948,
#  'honi': 3689,
#  'please': 5589,
#  'call': 1714,
#  'customer': 2267,
#  'service': 6398,
#  'representative': 6074,
#  '0800': 43,
#  '169': 342,
#  '6031': 633,
#  '10am9pm': 266,
#  'guaranteed': 3451,
#  '1000': 252,
#  'cash': 1798,
#  '5000': 594,
#  'prize': 5773,
#  'yeah': 8146,
#  'worse': 8023,
#  'great': 3423,
#  'trip': 7438,
#  'india': 3879,
#  'bring': 1616,
#  'light': 4373,
#  'everyone': 2835,
#  'project': 5802,
#  'lucky': 4526,
#  'see': 6353,
#  'smile': 6620,
#  'bye': 1696,
#  'abiola': 835,
#  'ic': 3806,
#  'lotta': 4480,
#  'childporn': 1920,
#  'cars': 1794,
#  'yup': 8217,
#  'im': 3838,
#  'free': 3157,
#  'tbspersolvo': 7114,
#  'chasing': 1869,
#  'us': 7611,
#  'since': 6540,
#  'sept': 6391,
#  'forå': 3139,
#  '38': 503,
#  'definitely': 2384,
#  'paying': 5455,
#  'thanks': 7194,
#  'information': 3891,
#  'ignore': 3828,
#  'kath': 4139,
#  'manchester': 4611,
#  'time': 7290,
#  'youll': 8194,
#  'need': 5023,
#  'near': 5015,
#  'campus': 1748,
#  'huh': 3764,
#  'cant': 1759,
#  'thk': 7243,
#  'oredi': 5317,
#  'many': 4620,
#  'pages': 5377,
#  'ya': 8130,
#  'ok': 5242,
#  'dinner': 2485,
#  'cos': 2159,
#  'shopping': 6475,
#  'wif': 7915,
#  'darren': 2314,
#  'jus': 4111,
#  'called': 1728,
#  'ask': 1189,
#  'wat': 7800,
#  'present': 5738,
#  'wan': 7777,
#  'lor': 4465,
#  'started': 6823,
#  'guessing': 3463,
#  'finally': 3026,
#  'guessed': 3460,
#  'like': 4376,
#  'ltgt': 4518,
#  'question': 5876,
#  'send': 6377,
#  'bec': 1376,
#  'temple': 7152,
#  'na': 4975,
#  'urgent': 7600,
#  'mobile': 4836,
#  'awarded': 1264,
#  '2000': 383,
#  'bonus': 1527,
#  'caller': 1729,
#  '5903': 610,
#  'final': 3024,
#  'try': 7457,
#  'contact': 2118,
#  'landline': 4270,
#  '09064019788': 211,
#  'box42wr29c': 1571,
#  '150ppm': 328,
#  'datingi': 2323,
#  'two': 7494,
#  'sent': 6386,
#  'text': 7175,
#  'talk': 7083,
#  'sport': 6776,
#  'radio': 5894,
#  'last': 4285,
#  'week': 7842,
#  'connection': 2108,
#  'coincidence': 2017,
#  'tagged': 7071,
#  'friends': 3183,
#  'seemed': 6359,
#  'count': 2174,
#  'madamregret': 4574,
#  'disturbancemight': 2521,
#  'receive': 5973,
#  'reference': 6003,
#  'check': 1882,
#  'dlf': 2530,
#  'premaricakindly': 5726,
#  'informedrgdsrakheshkerala': 3893,
#  'super': 6993,
#  'msg': 4916,
#  'danalla': 2298,
#  'timing': 7297,
#  'oh': 5236,
#  'rite': 6162,
#  'well': 7858,
#  'best': 1421,
#  'mate': 4651,
#  'pete': 5505,
#  'went': 7866,
#  '2geva': 435,
#  'longer': 4452,
#  'congrats': 2105,
#  '3g': 510,
#  'videophones': 7687,
#  '09061744553': 196,
#  'videochat': 7686,
#  'wid': 7913,
#  'ur': 7597,
#  'mates': 4652,
#  'play': 5579,
#  'java': 4037,
#  'games': 3243,
#  'dload': 2531,
#  'polyh': 5638,
#  'music': 4960,
#  'noline': 5117,
#  'rentl': 6060,
#  'bx420': 1692,
#  'ip4': 3952,
#  '5we': 628,
#  '150pm': 317,
#  'sorry': 6701,
#  'da': 2281,
#  'gone': 3360,
#  'mad': 4570,
#  'pending': 5472,
#  'works': 8010,
#  'finish': 3036,
#  'watching': 7803,
#  'tv': 7482,
#  'come': 2039,
#  'tomorrow': 7353,
#  'di': 2447,
#  'kkhow': 4203,
#  'business': 1678,
#  'velly': 7666,
#  'yes': 8158,
#  'tell': 7143,
#  'car': 1768,
#  'keys': 4162,
#  'purse': 5852,
#  'still': 6864,
#  'playing': 5585,
#  'gautham': 3260,
#  'ay': 1272,
#  'wana': 7779,
#  'meet': 4699,
#  'satì': 6284,
#  'wkg': 7965,
#  'sat': 6274,
#  'dont': 2568,
#  'forget': 3120,
#  'though': 7253,
#  'walk': 7764,
#  'beside': 1420,
#  'keeping': 4148,
#  'heart': 3566,
#  'warm': 7789,
#  'home': 3675,
#  'within': 7956,
#  'min': 4775,
#  'double': 2580,
#  'mins': 4787,
#  'txts': 7503,
#  '6months': 666,
#  'bluetooth': 1510,
#  'orange': 5309,
#  'available': 1246,
#  'sony': 6688,
#  'nokia': 5112,
#  'motorola': 4898,
#  'phones': 5526,
#  'mobileupd8': 4840,
#  '08000839402': 46,
#  'call2optoutn9dx': 1721,
#  'put': 5857,
#  'party': 5429,
#  'study': 6927,
#  'lightly': 4374,
#  'draw': 2597,
#  'custom': 2266,
#  'checkboxes': 1883,
#  'hardcore': 3530,
#  'fast': 2951,
#  'approaching': 1131,
#  'wish': 7946,
#  'new': 5052,
#  'year': 8148,
#  'sankranti': 6262,
#  'republic': 6075,
#  'day': 2329,
#  'valentines': 7645,
#  'shivratri': 6465,
#  'ugadi': 7514,
#  'fools': 3107,
#  'may': 4672,
#  'independence': 3877,
#  'friendshipmotherfatherteacherschildrens': 3185,
#  'amp': 1040,
#  'birthday': 1463,
#  'ganesh': 3246,
#  'festival': 2990,
#  'dasara': 2316,
#  'diwali': 2526,
#  'christmas': 1946,
#  'mornings': 4887,
#  'afternoons': 932,
#  'evenings': 2825,
#  'nights': 5076,
#  'rememberi': 6042,
#  'first': 3049,
#  'wishing': 7950,
#  'theseyours': 7225,
#  'raj': 5901,
#  'dude': 2639,
#  'pisces': 5556,
#  'aquarius': 1141,
#  'daily': 2293,
#  'ûò': 8245,
#  'favour': 2968,
#  'hear': 3563,
#  'six': 6563,
#  'chances': 1848,
#  'win': 7927,
#  '100': 251,
#  '20000': 384,
#  'pounds': 5687,
#  'txt': 7495,
#  'csh11': 2236,
#  '87575': 768,
#  'cost': 2161,
#  '150pday': 314,
#  '6days': 660,
#  '16': 340,
#  'tsandcs': 7462,
#  'apply': 1122,
#  'reply': 6068,
#  'hl': 3644,
#  'info': 3889,
#  'important': 3849,
#  'prevent': 5751,
#  'dehydration': 2388,
#  'giving': 3325,
#  'enough': 2769,
#  'fluids': 3085,
#  'inperialmusic': 3909,
#  'listening2the': 4408,
#  'weirdest': 7854,
#  'track': 7403,
#  'ever': 2828,
#  'byåóleafcutter': 1697,
#  'johnåósounds': 4076,
#  'insects': 3911,
#  'molestedsomeone': 4855,
#  'plumbingremixed': 5601,
#  'evil': 2843,
#  'men': 4722,
#  'acid': 868,
#  'mm': 4823,
#  'entirely': 2776,
#  'sure': 7009,
#  'understood': 7546,
#  'hey': 3612,
#  'ho': 3660,
#  'weekend': 7844,
#  'skype': 6578,
#  'later': 4293,
#  'message': 4738,
#  'offer': 5216,
#  'want': 7782,
#  'crave': 2204,
#  'sweet': 7036,
#  'arabian': 1144,
#  'steed': 6848,
#  'mmmmmm': 4826,
#  'yummy': 8213,
#  'ill': 3835,
#  'meeting': 4702,
#  'borrow': 1546,
#  'bag': 1296,
#  'brother': 1631,
#  'genius': 3284,
#  'said': 6244,
#  'right': 6143,
#  'giggle': 3313,
#  'saw': 6291,
#  'would': 8031,
#  'possibly': 5673,
#  'person2die': 5495,
#  'nvq': 5188,
#  'much': 4932,
#  'could': 2170,
#  'join': 4077,
#  'uks': 7525,
#  'horniest': 3706,
#  'dogging': 2549,
#  'sex': 6410,
#  '2nite': 452,
#  'sign': 6524,
#  'follow': 3098,
#  'instructions': 3922,
#  'entry': 2780,
#  '69888': 656,
#  'nytec2a3lpmsg150p': 5194,
#  'receiving': 5976,
#  'weeks': 7847,
#  'triple': 7439,
#  'echo': 2683,
#  'ringtone': 6152,
#  'shortly': 6485,
#  'enjoy': 2763,
#  'agree': 949,
#  'stop': 6877,
#  'thinkin': 7237,
#  'ipad': 3953,
#  'macho': 4567,
#  'wait': 7754,
#  'lect': 4327,
#  'havent': 3546,
#  'fine': 3031,
#  'safe': 6240,
#  'coming': 2047,
#  'friday': 3177,
#  'leave': 4324,
#  'pongaldo': 5644,
#  'news': 5057,
#  'work': 8003,
#  'place': 5564,
#  'babe': 1281,
#  'far': 2947,
#  'spunout': 6788,
#  'spk': 6762,
#  'mo': 4832,
#  'dead': 2341,
#  'wrld': 8046,
#  'sleeping': 6584,
#  'sofa': 6655,
#  'ive': 4006,
#  'latest': 4295,
#  'version': 7673,
#  'feel': 2978,
#  'dick': 2454,
#  'keep': 4147,
#  'texts': 7186,
#  'facebook': 2910,
#  'messages': 4744,
#  'sup': 6992,
#  'town': 7400,
#  'excellent': 2858,
#  'spent': 6751,
#  'years': 8149,
#  'air': 967,
#  'force': 3113,
#  'iraq': 3959,
#  'afghanistan': 925,
#  'stable': 6802,
#  'honest': 3683,
#  'traveling': 7423,
#  'god': 3343,
#  'blessget': 1489,
#  'sleep': 6582,
#  'deari': 2351,
#  'pray': 5713,
#  'didnt': 2458,
#  'holla': 3671,
#  'looking': 4458,
#  'buy': 1683,
#  '4the': 585,
#  'driving': 2616,
#  'test': 7170,
#  'yet': 8170,
#  'plz': 5603,
#  'note': 5139,
#  'anyone': 1090,
#  'calling': 1734,
#  'co': 2002,
#  'asks': 1194,
#  'type': 7507,
#  'disconnect': 2506,
#  'callcoz': 1725,
#  'iz': 4009,
#  'attempt': 1220,
#  'terrorist': 7166,
#  'make': 4597,
#  'use': 7615,
#  'sim': 6534,
#  'card': 1769,
#  'itz': 4003,
#  'confirmd': 2099,
#  'verified': 7670,
#  'cnn': 2001,
#  'ibn': 3803,
#  'seeing': 6355,
#  'missed': 4806,
#  'dear': 2348,
#  'gr8': 3399,
#  'hi': 3618,
#  'dis': 2498,
#  'yijue': 8174,
#  'gek1510': 3280,
#  'guess': 3459,
#  'whenever': 7889,
#  'hold': 3665,
#  'connections': 2109,
#  'maybe': 4674,
#  'hour': 3720,
#  'subscribed': 6949,
#  'content': 2122,
#  'uk': 7522,
#  'per': 5478,
#  '10': 250,
#  '82324': 729,
#  'helpline': 3596,
#  '08706091795': 79,
#  'ans': 1074,
#  'bslvyl': 1641,
#  'via': 7677,
#  'fullonsmscom': 3216,
#  'words': 8000,
#  'thnx': 7248,
#  'guys': 3473,
#  'wasnt': 7796,
#  'washob': 7795,
#  'nobbing': 5099,
#  'night': 5073,
#  'nickey': 5069,
#  'platt': 5578,
#  'instead': 3921,
#  'darlin': 2310,
#  'trouble': 7443,
#  'ijust': 3830,
#  'talked': 7085,
#  'mum': 4944,
#  'morning': 4886,
#  'really': 5956,
#  'goin': 3349,
#  'soon': 6691,
#  'handsome': 3511,
#  'finding': 3030,
#  'job': 4069,
#  'lazy': 4309,
#  'working': 8007,
#  'towards': 7399,
#  'getting': 3304,
#  'net': 5041,
#  'mummy': 4946,
#  'wheres': 7895,
#  'boytoy': 1580,
#  'miss': 4804,
#  'lol': 4445,
#  'warned': 7790,
#  'sprint': 6785,
#  'slow': 6602,
#  'prolly': 5804,
#  'around': 1168,
#  'going': 3351,
#  'bus': 1675,
#  'kkwhere': 4208,
#  'youhow': 8190,
#  'performed': 5485,
#  'sno': 6644,
#  'competition': 2060,
#  'evening': 2824,
#  'roger': 6173,
#  'break': 1596,
#  'one': 5267,
#  'stuff': 6929,
#  'fr': 3147,
#  'show': 6495,
#  'wot': 8027,
#  'say': 6292,
#  'dust': 2654,
#  'way': 7812,
#  'shall': 6431,
#  'book': 1530,
#  'chez': 1902,
#  'jules': 4101,
#  'half': 3496,
#  'eight': 2713,
#  'thats': 7206,
#  'thing': 7233,
#  'bw': 1690,
#  'itll': 3990,
#  'tough': 7396,
#  'hope': 3697,
#  'youåõre': 8208,
#  'fun': 3217,
#  'without': 7957,
#  'jess': 4056,
#  'always': 1025,
#  'even': 2823,
#  'spirit': 6759,
#  'bb': 1349,
#  'trying': 7459,
#  'aiyar': 973,
#  'poor': 5650,
#  'give': 3323,
#  'support': 7000,
#  'jia': 4063,
#  'lots': 4478,
#  'used': 7616,
#  'ones': 5269,
#  'model': 4847,
#  'doesnt': 2544,
#  'help': 3589,
#  'youi': 8191,
#  'hell': 3582,
#  'match': 4649,
#  'reach': 5936,
#  'telling': 7144,
#  'probably': 5778,
#  'gotta': 3390,
#  'leo': 4341,
#  'covers': 2188,
#  'face': 2908,
#  'kisses': 4193,
#  'rounderso': 6191,
#  'required': 6079,
#  'part': 5422,
#  'initiate': 3901,
#  'understand': 7544,
#  'foot': 3108,
#  'bored': 1541,
#  'housewives': 3726,
#  'chat': 1871,
#  'date': 2319,
#  '08717507711': 126,
#  'btnational': 1646,
#  'rate': 5920,
#  '10pmin': 269,
#  'landlines': 4272,
#  'reg': 6013,
#  'ciao': 1952,
#  '07xxxxxxxxx': 42,
#  '020603': 6,
#  '2nd': 450,
#  '09066362231': 223,
#  'asap': 1183,
#  'box97n7qp': 1574,
#  'loosu': 4464,
#  'go': 3336,
#  'hospital': 3711,
#  'de': 2340,
#  'let': 4349,
#  'careless': 1779,
#  'chosen': 1942,
#  '350': 494,
#  'award': 1263,
#  'claim': 1960,
#  'number': 5177,
#  '09066364311': 224,
#  'collect': 2025,
#  'selected': 6365,
#  'valued': 7650,
#  'sister': 6556,
#  'cleared': 1976,
#  'round': 6190,
#  'birla': 1459,
#  'soft': 6656,
#  'yesterday': 8169,
#  'gram': 3406,
#  'usually': 7630,
#  'runs': 6224,
#  'eighth': 2714,
#  'smarter': 6611,
#  'gets': 3300,
#  'almost': 1010,
#  'whole': 7905,
#  'second': 6340,
#  'ten': 7153,
#  'rs': 6204,
#  'shelf': 6442,
#  'egg': 2706,
#  'beautiful': 1373,
#  'truth': 7455,
#  'gravity': 3420,
#  'read': 5942,
#  'carefully': 1777,
#  'feels': 2982,
#  'someone': 6668,
#  'heavy': 3574,
#  'leaves': 4325,
#  'hiya': 3643,
#  'stu': 6919,
#  '2im': 439,
#  'truble': 7446,
#  'moment': 4857,
#  'evone': 2847,
#  'hates': 3542,
#  'av': 1243,
#  'wont': 7989,
#  'bck': 1358,
#  'luv': 4537,
#  'dan': 2297,
#  'happen': 3519,
#  'behave': 1401,
#  'iouri': 3950,
#  'told': 7342,
#  'story': 6891,
#  'times': 7292,
#  'already': 1014,
#  'grumpy': 3447,
#  'old': 5258,
#  'people': 5476,
#  'mom': 4856,
#  'better': 1429,
#  'lying': 4547,
#  'jokes': 4083,
#  'prob': 5777,
#  'gained': 3235,
#  'kg': 4165,
#  'took': 7370,
#  'blood': 1500,
#  'sugar': 6970,
#  'tests': 7172,
#  'pressure': 5745,
#  'normal': 5132,
#  'limits': 4385,
#  'worries': 8019,
#  'ride': 6142,
#  'equally': 2786,
#  'uneventful': 7550,
#  'pesky': 5503,
#  'cyclists': 2279,
#  'came': 1744,
#  'hostel': 3714,
#  'class': 1967,
#  'hrishi': 3740,
#  'network': 5046,
#  'urgnt': 7604,
#  'sms': 6630,
#  'whatever': 7884,
#  'juliana': 4102,
#  'baby': 1285,
#  'got': 3387,
#  'wanting': 7785,
#  'allday': 1003,
#  'piss': 5557,
#  'phone': 5522,
#  'xxx': 8120,
#  'mmm': 4824,
#  'fuck': 3206,
#  'merry': 4734,
#  'gibbs': 3308,
#  'unsoldmike': 7570,
#  'hussey': 3790,
#  'supposed': 7005,
#  'gt': 3449,
#  'account': 861,
#  'detailsi': 2434,
#  'youmy': 8195,
#  'ard': 1147,
#  'dat': 2317,
#  'speed': 6742,
#  'dating': 2322,
#  'speedchat': 6743,
#  '80155': 712,
#  'em': 2734,
#  'swap': 7028,
#  'chatter': 1875,
#  'chat80155': 1872,
#  'pobox36504w45wq': 5613,
#  '150pmsg': 321,
#  'rcd': 5930,
#  'forwarded': 3137,
#  'thought': 7254,
#  'ohi': 5237,
#  'asked': 1191,
#  'hahatake': 3488,
#  'office': 5221,
#  'lap': 4279,
#  'room': 6182,
#  'shut': 6511,
#  'hmm': 3649,
#  'youre': 8199,
#  'forgiven': 3123,
#  'fancy': 2943,
#  'meetin': 4701,
#  'cha': 1838,
#  'åð': 8233,
#  'hav': 3544,
#  'lil': 4381,
#  'beverage': 1431,
#  'ring': 6149,
#  'l8r': 4245,
#  'quite': 5884,
#  'tired': 7300,
#  'vpist': 7732,
#  'hours': 3722,
#  'dahow': 2291,
#  'todays': 7332,
#  'marriage': 4634,
#  'function': 3218,
#  'also': 1019,
#  'family': 2937,
#  'rhode': 6137,
#  'island': 3973,
#  'wherever': 7896,
#  'leaving': 4326,
#  'alone': 1011,
#  'bong': 1526,
#  'hadya': 3484,
#  'sapna': 6266,
#  'aunty': 1238,
#  'manege': 4615,
#  'yday': 8145,
#  'hogidhechinnu': 3662,
#  'full': 3215,
#  'weak': 7817,
#  'swalpa': 7026,
#  'black': 1472,
#  'agidhane': 945,
#  'sir': 6550,
#  'able': 837,
#  'raise': 5899,
#  'dad': 2285,
#  'however': 3732,
#  'rest': 6104,
#  'mid': 4761,
#  'feb': 2974,
#  'amount': 1039,
#  'short': 6481,
#  'hoping': 3704,
#  'aight': 965,
#  'money': 4864,
#  'dare': 2306,
#  'change': 1849,
#  'top': 7377,
#  'polyphonic': 5640,
#  'tones': 7358,
#  '087018728737': 73,
#  'national': 5000,
#  'toppoly': 7381,
#  'tune': 7477,
#  'every': 2829,
#  'subpoly': 6947,
#  '81618': 724,
#  'pole': 5630,
#  'unsub': 7572,
#  '08718727870': 141,
#  'drink': 2608,
#  'sipix': 6548,
#  'digital': 2476,
#  'camera': 1745,
#  '09061221061': 186,
#  'delivery': 2399,
#  '28days': 421,
#  'cs': 2235,
#  'box177': 1562,
#  'm221bp': 4551,
#  '2yr': 470,
#  'warranty': 7793,
#  'på': 5864,
#  '399': 505,
#  'updatenow': 7582,
#  'xmas': 8114,
#  'sonyericsson': 6689,
#  'call2optoutf4q': 1718,
#  'wow': 8034,
#  'common': 2052,
#  'freak': 3153,
#  'unless': 7562,
#  'chop': 1939,
#  'drunkard': 2629,
#  'hair': 3491,
#  'tonight': 7364,
#  'wats': 7809,
#  'plan': 5570,
#  'pick': 5534,
#  'miserable': 4800,
#  'side': 6520,
#  'effects': 2700,
#  'birth': 1461,
#  'control': 2130,
#  'massive': 4645,
#  'gut': 3471,
#  'wrenching': 8038,
#  'cramps': 2199,
#  'months': 4878,
#  'another': 1073,
#  'tc': 7115,
#  'wwwtcbiz': 8092,
#  '18': 345,
#  '150pmin': 319,
#  'polo': 5633,
#  'ltd': 4514,
#  'suite': 6974,
#  '373': 500,
#  'london': 4448,
#  'w1j': 7739,
#  '6hl': 661,
#  'busy': 1679,
#  'belly': 1408,
#  'dreams': 2601,
#  'ahmad': 956,
#  'adoring': 904,
#  'kiss': 4192,
#  'lateso': 4294,
#  'morningtake': 4888,
#  'dreamsu': 2603,
#  'meummifyingbye': 4755,
#  'request': 6076,
#  'rs5': 6205,
#  'transfered': 7416,
#  'pain': 5379,
#  'urination': 7606,
#  'else': 2731,
#  'run': 6221,
#  'away': 1265,
#  'frm': 3189,
#  'slowly': 6605,
#  'kills': 4181,
#  'mean': 4682,
#  'website': 7832,
#  'settled': 6405,
#  'lets': 4350,
#  'kallis': 4127,
#  'ready': 5946,
#  'bat': 1337,
#  'innings': 3905,
#  'user': 7619,
#  '0796xxxxxx': 40,
#  'day2': 2330,
#  'find': 3029,
#  'log': 4436,
#  'onto': 5280,
#  'httpwwwurawinnercom': 3753,
#  'theres': 7223,
#  'fantastic': 2945,
#  'prizeawaiting': 5774,
#  'funny': 3223,
#  'fact': 2912,
#  'nobody': 5101,
#  'teaches': 7125,
#  'volcanoes': 7724,
#  'erupt': 2797,
#  'tsunamis': 7466,
#  'arise': 1158,
#  'hurricanes': 3783,
#  'sway': 7031,
#  'aroundn': 1169,
#  'hw': 3794,
#  'choose': 1937,
#  'wife': 7916,
#  'natural': 5004,
#  'disasters': 2502,
#  'happens': 3524,
#  'dialogue': 2449,
#  'cute': 2271,
#  'reltnship': 6035,
#  'wen': 7863,
#  'die': 2462,
#  'weekly': 7846,
#  'comp': 2054,
#  'chance': 1847,
#  'ipod': 3957,
#  'pod': 5624,
#  '80182': 714,
#  'std': 6841,
#  'tcs': 7118,
#  '08452810073': 65,
#  'details': 2433,
#  'whenevr': 7890,
#  'sad': 6238,
#  'gray': 3422,
#  'remembr': 6043,
#  'listn': 4409,
#  'watevr': 7806,
#  'wanna': 7780,
#  'little': 4414,
#  'whileamp': 7900,
#  'promise': 5806,
#  'cashbalance': 1799,
#  'currently': 2261,
#  '500': 593,
#  'maximize': 4669,
#  'cashin': 1801,
#  '86688': 760,
#  'cc': 1819,
#  '08718720201': 132,
#  'po': 5605,
#  'box': 1560,
#  '11414': 275,
#  'tcrw1': 7117,
#  'teacher': 7124,
#  'look': 4454,
#  'cut': 2270,
#  'bit': 1465,
#  'left': 4329,
#  'swing': 7045,
#  '448712404000please': 554,
#  '08712404000': 98,
#  'immediately': 3845,
#  'waiting': 7757,
#  'sooner': 6693,
#  'gorgeous': 3383,
#  'pix': 5560,
#  'cumming': 2254,
#  'thank': 7193,
#  'post': 5674,
#  'wrote': 8050,
#  'ritten': 6163,
#  'sit': 6557,
#  'feeling': 2980,
#  'angry': 1059,
#  'hit': 3636,
#  'checked': 1884,
#  'wouldnt': 8033,
#  'clean': 1973,
#  'fold': 3095,
#  'laundry': 4301,
#  'etc': 2810,
#  'least': 4321,
#  'bed': 1382,
#  'returned': 6123,
#  'hes': 3607,
#  'saying': 6295,
#  'order': 5314,
#  'liao': 4354,
#  'yellow': 8152,
#  'rose': 6187,
#  'frndship': 3192,
#  'misscall': 4805,
#  'frndz': 3195,
#  'calls': 1736,
#  '6missed': 665,
#  'marry': 4637,
#  'lover': 4494,
#  '123': 285,
#  'congratulations': 2106,
#  '1450': 304,
#  '09050002311': 163,
#  'b4280703': 1276,
#  'tcsstop': 7121,
#  '08718727868': 140,
#  ...}

# %%
# How are these vectors stored?
X_test_vect[0]
# Out:
# <1x8247 sparse matrix of type '<class 'numpy.float64'>'
# 	with 11 stored elements in Compressed Sparse Row format>

# %%
# Can we convert the vectors to arrays?
X_test_vect[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# ### Fit RandomForestClassifier On Top Of Vectors

# %%
# Fit a basic Random Forest model on these vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect, y_train.values.ravel())

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect)

# %%
# Evaluate the predictions of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test['label']).sum()/len(y_pred), 3)))
# Out:
# Precision: 1.0 / Recall: 0.826 / Accuracy: 0.978
