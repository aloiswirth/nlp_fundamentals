# %% [markdown]
# # Compare NLP Techniques: Build Model On TF-IDF Vectors

# %% [markdown]
# ### Read In Cleaned Text

# %%
# Load the cleaned training and test sets
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

X_train = pd.read_csv('../../../data/X_train.csv')
X_test = pd.read_csv('../../../data/X_test.csv')
y_train = pd.read_csv('../../../data/y_train.csv')
y_test = pd.read_csv('../../../data/y_test.csv')

X_train.head()
# Out:
#                                           clean_text
# 0                            ['meet', 'lunch', 'la']
# 1  ['lovely', 'smell', 'bus', 'aint', 'tobacco', '']
# 2  ['rose', 'redred', 'bloodblood', 'heartheart',...
# 3  ['yeah', 'usual', 'guys', 'town', 'therere', '...
# 4                                   ['call', 'meet']

# %% [markdown]
# ### Create TF-IDF Vectors

# %%
# Instantiate and fit a TFIDF vectorizer and then use that trained vectorizer
# to transform the messages in the training and test sets
tfidf_vect = TfidfVectorizer()
tfidf_vect.fit(X_train['clean_text'])
X_train_vect = tfidf_vect.transform(X_train['clean_text'])
X_test_vect = tfidf_vect.transform(X_test['clean_text'])

# %%
# What words did the vectorizer learn?
tfidf_vect.vocabulary_
# Out:
# {'meet': 4712,
#  'lunch': 4543,
#  'la': 4250,
#  'lovely': 4503,
#  'smell': 6658,
#  'bus': 1675,
#  'aint': 969,
#  'tobacco': 7385,
#  'rose': 6219,
#  'redred': 6038,
#  'bloodblood': 1492,
#  'heartheart': 3566,
#  'send': 6412,
#  'tis': 7363,
#  'ur': 7662,
#  'friends': 3176,
#  'including': 3858,
#  'like': 4381,
#  'get': 3291,
#  'back': 1280,
#  '1u': 366,
#  'poor': 5682,
#  'relation': 6063,
#  '2u': 457,
#  'need': 5052,
#  'support': 7058,
#  '3u': 520,
#  'frnd': 3184,
#  'many': 4638,
#  '4some1': 577,
#  'luvs': 4551,
#  'some1': 6709,
#  'praying': 5743,
#  'god': 3338,
#  'marry': 4656,
#  'try': 7519,
#  'yeah': 8216,
#  'usual': 7693,
#  'guys': 3470,
#  'town': 7463,
#  'therere': 7279,
#  'definitely': 2395,
#  'people': 5512,
#  'around': 1149,
#  'know': 4217,
#  'call': 1715,
#  'nothing': 5174,
#  'splwat': 6816,
#  'abt': 838,
#  'whr': 7981,
#  'ru': 6239,
#  'real': 5990,
#  'tho': 7308,
#  'sucks': 7015,
#  'cant': 1764,
#  'even': 2824,
#  'cook': 2139,
#  'whole': 7978,
#  'electricity': 2732,
#  'im': 3829,
#  'hungry': 3766,
#  'donno': 2573,
#  'genes': 3280,
#  'something': 6716,
#  'ok': 5277,
#  'enjoy': 2767,
#  'shows': 6539,
#  'sez': 6455,
#  'hows': 3730,
#  'de': 2349,
#  'arab': 1127,
#  'boy': 1567,
#  'hope': 3697,
#  'good': 3360,
#  'give': 3316,
#  'love': 4500,
#  'evry1': 2850,
#  'ya': 8200,
#  'eshxxxxxxxxxxx': 2805,
#  'eastenders': 2683,
#  'tv': 7545,
#  'quiz': 5925,
#  'flower': 3074,
#  'dot': 2586,
#  'compare': 2060,
#  'violet': 7767,
#  'tulip': 7537,
#  'lily': 4387,
#  'txt': 7558,
#  '84025': 737,
#  'chance': 1853,
#  'win': 7999,
#  '100': 246,
#  'cash': 1804,
#  'wkent150p16': 8036,
#  'nw': 5221,
#  'came': 1747,
#  'hme': 3650,
#  'da': 2282,
#  'wat': 7869,
#  'makes': 4614,
#  'thk': 7302,
#  'ill': 3826,
#  'fall': 2920,
#  'actually': 883,
#  'quite': 5923,
#  'prone': 5843,
#  'falls': 2923,
#  'lucky': 4536,
#  'dad': 2287,
#  'home': 3676,
#  'ask': 1174,
#  'come': 2038,
#  'fetch': 2982,
#  'already': 1011,
#  'go': 3330,
#  'chase': 1869,
#  'run': 6252,
#  'shes': 6490,
#  'crossing': 2231,
#  'street': 6950,
#  'whatever': 7956,
#  'juliana': 4104,
#  'want': 7849,
#  'sounds': 6761,
#  'someone': 6712,
#  'testing': 7223,
#  'would': 8098,
#  'sayy': 6332,
#  'custom': 2268,
#  'officer': 5256,
#  'discount': 2520,
#  'oh': 5270,
#  'yan': 8207,
#  'jiu': 4061,
#  'liao': 4356,
#  'sat': 6311,
#  'bugis': 1657,
#  'vill': 7762,
#  'one': 5303,
#  'frm': 3183,
#  '10': 245,
#  'den': 2415,
#  'hop': 3696,
#  'parco': 5445,
#  'nb': 5038,
#  'sun': 7038,
#  'cine': 1952,
#  '1030': 258,
#  'orc': 5344,
#  'mrt': 4933,
#  'hip': 3637,
#  'dont': 2574,
#  'thnk': 7305,
#  'wrong': 8118,
#  'calling': 1736,
#  'us': 7675,
#  'bull': 1662,
#  'plan': 5602,
#  'floating': 3068,
#  'ikea': 3822,
#  'without': 8028,
#  'care': 1778,
#  'world': 8080,
#  'live': 4420,
#  'mess': 4753,
#  'another': 1066,
#  'day': 2336,
#  'said': 6279,
#  'woke': 8050,
#  'yup': 8292,
#  'wun': 8130,
#  'believe': 1397,
#  'really': 5998,
#  'neva': 5075,
#  'msg': 4936,
#  'sent': 6423,
#  'shuhui': 6546,
#  'got': 3382,
#  'job': 4065,
#  'wiproyou': 8014,
#  'every': 2831,
#  'thing': 7291,
#  'life': 4367,
#  'years': 8219,
#  'spoons': 6826,
#  'okay': 5278,
#  'hey': 3617,
#  'mr': 4930,
#  'whats': 7957,
#  'name': 5013,
#  'bill': 1441,
#  'brison': 1615,
#  'book': 1520,
#  'language': 4279,
#  'words': 8070,
#  'aight': 968,
#  'see': 6385,
#  'bit': 1458,
#  'wats': 7881,
#  'decision': 2379,
#  'gas': 3252,
#  'money': 4882,
#  'gang': 3243,
#  'grand': 3402,
#  'nature': 5034,
#  'adventure': 914,
#  'interested': 3925,
#  'sorry': 6745,
#  'later': 4296,
#  'hi': 3623,
#  'moved': 4922,
#  'in2': 3851,
#  'pub': 5870,
#  'great': 3417,
#  'cud': 2249,
#  'test': 7222,
#  'earlier': 2671,
#  'appreciate': 1113,
#  'tomorrow': 7416,
#  'please': 5621,
#  'tell': 7195,
#  'car': 1773,
#  'keys': 4164,
#  'purse': 5890,
#  'take': 7125,
#  'exam': 2856,
#  'march': 4644,
#  'secret': 6377,
#  'admirer': 900,
#  'reveal': 6159,
#  'thinks': 7298,
#  'special': 6782,
#  '09065174042': 208,
#  'opt': 5334,
#  'reply': 6106,
#  'stop': 6929,
#  '150': 300,
#  'per': 5514,
#  'recd': 6011,
#  'cust': 2265,
#  '07821230901': 35,
#  'goin': 3347,
#  'workout': 8078,
#  'lor': 4476,
#  'muz': 4992,
#  'lose': 4480,
#  'fats': 2951,
#  'creepy': 2219,
#  'crazy': 2209,
#  'fact': 2905,
#  'leave': 4325,
#  'think': 7294,
#  'addie': 891,
#  'goes': 3344,
#  'school': 6342,
#  'tues': 7532,
#  'wed': 7903,
#  'thought': 7313,
#  'could': 2172,
#  'dinner': 2500,
#  'treat': 7495,
#  'seem': 6390,
#  'things': 7293,
#  'went': 7937,
#  'well': 7929,
#  'doctors': 2549,
#  'reminds': 6087,
#  'still': 6917,
#  '2godid': 432,
#  'little': 4419,
#  'left': 4330,
#  'lounge': 4496,
#  'wanted': 7851,
#  'wish': 8018,
#  'happy': 3525,
#  'new': 5079,
#  'year': 8218,
#  'talk': 7133,
#  'legal': 4333,
#  'advice': 916,
#  'gary': 3251,
#  'split': 6814,
#  'person': 5531,
#  'make': 4613,
#  'trip': 7503,
#  'ptbo': 5868,
#  'everything': 2839,
#  'babe': 1270,
#  'ard': 1130,
#  'smth': 6679,
#  'size': 6605,
#  'elephant': 2733,
#  'tablets': 7115,
#  'shove': 6531,
#  'um': 7591,
#  'ass': 1183,
#  'right': 6175,
#  'wasnt': 7864,
#  'phoned': 5558,
#  'number': 5207,
#  'records': 6030,
#  'indicate': 3876,
#  'maybe': 4691,
#  'entitled': 2783,
#  '5000': 593,
#  'pounds': 5714,
#  'compensation': 2062,
#  'accident': 851,
#  'claim': 1958,
#  'free': 3146,
#  'pick': 5566,
#  'phone': 5556,
#  'pls': 5629,
#  'message': 4754,
#  'urgent': 7665,
#  'trying': 7521,
#  'contact': 2116,
#  'todays': 7394,
#  'draw': 2606,
#  '2000': 373,
#  'prize': 5803,
#  'guaranteed': 3450,
#  '09058094507': 171,
#  'land': 4271,
#  'line': 4394,
#  '3030': 473,
#  'valid': 7710,
#  '12hrs': 285,
#  'buy': 1686,
#  'juz': 4117,
#  'lar': 4283,
#  'sbut': 6333,
#  'luck2': 4534,
#  'catches': 1813,
#  'put': 5895,
#  'correct': 2154,
#  'work': 8073,
#  'today': 7388,
#  'use': 7678,
#  'half8th': 3494,
#  'sexychat': 6454,
#  'girls': 3314,
#  'waiting': 7826,
#  'text': 7227,
#  'night': 5102,
#  'chatting': 1877,
#  'service': 6436,
#  'rgent': 6167,
#  '2nd': 444,
#  'attempt': 1208,
#  'uu': 7698,
#  '1250': 282,
#  '09071512433': 230,
#  'b4': 1264,
#  '050703': 14,
#  'tcsbcm4235wc1n3xx': 7171,
#  'callcost': 1727,
#  '150ppm': 321,
#  'mobilesvary': 4857,
#  'maxå': 4688,
#  '50': 591,
#  '800': 697,
#  '09050000460': 156,
#  'j89': 4008,
#  'po': 5639,
#  'box245c2150pm': 1555,
#  'pay': 5486,
#  'ltgt': 4528,
#  'yrs': 8285,
#  'difficult': 2486,
#  'yun': 8289,
#  'buying': 1689,
#  'offer': 5250,
#  'plus': 5634,
#  'nottel': 5178,
#  'software': 6700,
#  'supervisor': 7053,
#  'find': 3018,
#  'students': 6974,
#  'havent': 3543,
#  'yet': 8243,
#  'aft': 932,
#  'yijue': 8248,
#  '11': 266,
#  'tmr': 7378,
#  'ugh': 7579,
#  'fuck': 3197,
#  'resubbing': 6145,
#  'eve': 2822,
#  'mobiles': 4855,
#  '2004': 376,
#  'must': 4986,
#  'nokia': 5146,
#  '89545': 780,
#  'collect': 2024,
#  'www4tcbiz': 8132,
#  '2optout': 448,
#  '08718726270150gbpmtmsg18': 136,
#  'txtauction': 7560,
#  'messageno': 4757,
#  'responcewhat': 6131,
#  'happend': 3517,
#  'elaborating': 2726,
#  'safety': 6276,
#  'aspects': 1182,
#  'issues': 3974,
#  'customer': 2269,
#  'annoncement': 1060,
#  'delivery': 2410,
#  '07046744435': 20,
#  'arrange': 1152,
#  'wont': 8061,
#  'christmas': 1945,
#  'merry': 4749,
#  'xmas': 8184,
#  'chill': 1924,
#  '6hrs': 658,
#  'sleep': 6625,
#  'pain': 5415,
#  'surgical': 7069,
#  'emergency': 2746,
#  'unfolds': 7615,
#  'dude': 2649,
#  'avatar': 1241,
#  '3d': 502,
#  'imp': 3840,
#  'point': 5660,
#  'flies': 3060,
#  'room': 6213,
#  'almost': 1007,
#  'tried': 7502,
#  'hittng': 3644,
#  'reflex': 6047,
#  'ride': 6174,
#  'equally': 2791,
#  'uneventful': 7614,
#  'pesky': 5539,
#  'cyclists': 2280,
#  'time': 7349,
#  'winner': 8008,
#  'ave': 1243,
#  'specially': 6786,
#  'selected': 6400,
#  'receive': 6014,
#  '1000': 247,
#  'holiday': 3671,
#  'flights': 3062,
#  'inc': 3852,
#  'speak': 6780,
#  'operator': 5327,
#  '0871277810710pmin': 106,
#  '18': 339,
#  'lol': 4454,
#  'alright': 1013,
#  'thinkin': 7296,
#  'haha': 3484,
#  'monthly': 4893,
#  'amount': 1035,
#  'terrible': 7216,
#  'anything': 1085,
#  'till': 7347,
#  '6months': 661,
#  'finishing': 3030,
#  'ha': 3477,
#  'wouldnt': 8100,
#  'say': 6327,
#  'didnt': 2472,
#  'read': 5985,
#  'way': 7883,
#  'seemed': 6391,
#  'judgementali': 4102,
#  'save': 6323,
#  'fridays': 3172,
#  'somewhere': 6722,
#  'fredericksburg': 3145,
#  'filthy': 3012,
#  'stories': 6941,
#  'sms': 6673,
#  'auction': 1218,
#  '7250i': 673,
#  'part': 5455,
#  '86021': 750,
#  'hgsuite3422lands': 3620,
#  'roww1jhl': 6226,
#  '16': 334,
#  'wereare': 7940,
#  'otherwise': 5363,
#  'nalla': 5011,
#  'adi': 897,
#  'entey': 2780,
#  'nattil': 5031,
#  'kittum': 4196,
#  'ttyl': 7530,
#  'coming': 2047,
#  'fine': 3020,
#  'babes': 1271,
#  'much': 4956,
#  'saw': 6326,
#  'scary': 6338,
#  'movie': 4924,
#  'yest': 8241,
#  'funny': 3218,
#  '2mrw': 442,
#  'afternoon': 934,
#  'mall': 4621,
#  'sumthinxx': 7037,
#  'height': 3576,
#  'confidence': 2094,
#  'aeronautics': 920,
#  'professors': 5824,
#  'wer': 7939,
#  'calld': 1729,
#  'amp': 1036,
#  'askd': 1175,
#  'sit': 6596,
#  'aeroplane': 921,
#  'aftr': 937,
#  'told': 7405,
#  'dat': 2323,
#  'plane': 5603,
#  'ws': 8122,
#  'made': 4589,
#  'dey': 2456,
#  'hurried': 3773,
#  'bt': 1642,
#  'move': 4921,
#  'saidif': 6280,
#  'finished': 3028,
#  'project': 5830,
#  'centre': 1839,
#  'mobile': 4854,
#  '11mths': 274,
#  'update': 7643,
#  'oranges': 5343,
#  'latest': 4298,
#  'colour': 2031,
#  'camera': 1748,
#  'unlimited': 7631,
#  'weekend': 7912,
#  'calls': 1739,
#  'upd8': 7642,
#  'freefone': 3150,
#  '08000839402': 44,
#  '2stoptx': 455,
#  'makin': 4616,
#  'weirdy': 7925,
#  'brownies': 1633,
#  'sister': 6594,
#  'awesome': 1256,
#  'cookies': 2141,
#  'took': 7433,
#  'pics': 5570,
#  'lookatme': 4465,
#  'thanks': 7242,
#  'purchase': 5884,
#  'video': 7751,
#  'clip': 1980,
#  'youve': 8279,
#  'charged': 1862,
#  '35p': 489,
#  'better': 1423,
#  'mmsto': 4846,
#  '32323': 482,
#  'stayin': 6893,
#  'extra': 2892,
#  'week': 7910,
#  'next': 5088,
#  'rugby': 6243,
#  'soon': 6733,
#  'ham': 3499,
#  'mu': 4955,
#  'sorting': 6752,
#  'narcotics': 5023,
#  'situation': 6601,
#  '123': 279,
#  'congratulations': 2104,
#  'weeks': 7915,
#  'competition': 2063,
#  '1450': 297,
#  '09050002311': 159,
#  'b4280703': 1266,
#  'tcsstop': 7173,
#  '08718727868': 139,
#  'newest': 5081,
#  'ûïharry': 8318,
#  'potter': 5710,
#  'order': 5346,
#  'phoenix': 5555,
#  'harry': 3533,
#  'answer': 1069,
#  'questions': 5917,
#  'first': 3039,
#  'among': 1032,
#  'readers': 5986,
#  'picking': 5568,
#  'various': 7719,
#  'points': 5661,
#  'supply': 7057,
#  'cds': 1828,
#  'store': 6938,
#  'choice': 1935,
#  'worth': 8094,
#  '500': 592,
#  'enter': 2775,
#  'weekly': 7914,
#  'music': 4984,
#  '87066': 756,
#  'tscs': 7525,
#  'wwwldewcomsubs161win150ppmx3': 8152,
#  'sac': 6265,
#  'score': 6347,
#  'big': 1437,
#  'hundredhe': 3763,
#  'set': 6440,
#  'batsman': 1339,
#  'gonna': 3358,
#  'let': 4350,
#  'cos': 2160,
#  'comes': 2042,
#  'bak': 1293,
#  'dont4get2text': 2575,
#  'feel': 2971,
#  'alone': 1008,
#  'shanilrakhesh': 6476,
#  'herethanksi': 3605,
#  'exchanged': 2860,
#  'uncut': 7606,
#  'diamond': 2465,
#  'stuffleaving': 6982,
#  'excellent': 2858,
#  'dino': 2501,
#  'prem': 5753,
#  'fantasy': 2937,
#  'football': 3102,
#  'sky': 6617,
#  'gamestar': 3240,
#  'active': 879,
#  'play': 5612,
#  '250k': 403,
#  'dream': 2610,
#  'team': 7180,
#  'scoring': 6349,
#  'starts': 6882,
#  'saturday': 6319,
#  'register': 6056,
#  'nowsky': 5193,
#  '88088': 768,
#  'polyphonic': 5672,
#  'tone': 7420,
#  'mob': 4852,
#  'pt2': 5867,
#  '87575': 763,
#  '1st': 362,
#  'txtin': 7562,
#  '150ptone': 325,
#  'hl': 3647,
#  '4info': 570,
#  'tick': 7338,
#  'different': 2485,
#  'styles': 6989,
#  'meeting': 4715,
#  'darren': 2319,
#  'godtaken': 3342,
#  'teethis': 7190,
#  'paining': 5418,
#  'long': 4461,
#  'exhausted': 2868,
#  'cuddle': 2250,
#  'nap': 5022,
#  'wot': 8095,
#  'weirdo': 7924,
#  'dear': 2358,
#  'sleeping': 6627,
#  'ah': 954,
#  'konw': 4230,
#  'waht': 7821,
#  'rael': 5936,
#  'friendship': 3178,
#  'gving': 3472,
#  'yuo': 8291,
#  'exmpel': 2870,
#  'jsut': 4100,
#  'ese': 2804,
#  'tihs': 7345,
#  'evrey': 2848,
#  'splleing': 6815,
#  'wrnog': 8117,
#  'sitll': 6598,
#  'raed': 5935,
#  'wihtuot': 7992,
#  'ayn': 1261,
#  'mitsake': 4832,
#  'goodnight': 3370,
#  'nice': 5093,
#  'sleepsweet': 6631,
#  'dreams': 2612,
#  'railway': 5939,
#  'days': 2340,
#  'tessypls': 7221,
#  'favor': 2958,
#  'convey': 2133,
#  'birthday': 1456,
#  'wishes': 8020,
#  'nimyapls': 5114,
#  'dnt': 2541,
#  'forget': 3111,
#  'shijas': 6494,
#  'sirsalam': 6592,
#  'alaikkumpride': 982,
#  'pleasure': 5624,
#  'tea': 7175,
#  'shopwe': 6518,
#  'pleased': 5622,
#  'qatarrakhesh': 5904,
#  'indianpls': 3874,
#  'numberrespectful': 5209,
#  'regards': 6055,
#  'smile': 6660,
#  'hppnss': 3733,
#  'drop': 2630,
#  'tear': 7181,
#  'sorrow': 6743,
#  'heart': 3563,
#  'mine': 4792,
#  'wil': 7994,
#  'forevr': 3109,
#  'goodfriend': 3365,
#  'tel': 7192,
#  'problem': 5810,
#  'chinatown': 1928,
#  'porridge': 5690,
#  'claypot': 1968,
#  'rice': 6170,
#  'yam': 8206,
#  'cake': 1706,
#  'fishhead': 3041,
#  'beehoon': 1382,
#  'either': 2722,
#  'eat': 2686,
#  'cheap': 1878,
#  'cafe': 1705,
#  'tok': 7401,
#  'nydc': 5224,
#  'somethin': 6715,
#  'inside': 3910,
#  'officestill': 5257,
#  'filling': 3007,
#  'formsdon': 3120,
#  'repeat': 6099,
#  'instructions': 3918,
#  'road': 6194,
#  'house': 3721,
#  'wherres': 7971,
#  'boytoy': 1571,
#  'looks': 4469,
#  'scrumptious': 6364,
#  'daddy': 2288,
#  'wants': 7853,
#  'happen': 3516,
#  'mon': 4878,
#  'thurs': 7333,
#  'leh': 4335,
#  'booked': 1521,
#  'noon': 5156,
#  'foreign': 3107,
#  'stamps': 6865,
#  'country': 2178,
#  'lecture': 4329,
#  'pussy': 5894,
#  'perfect': 5517,
#  'slowly': 6649,
#  'godi': 3339,
#  'youclean': 8260,
#  'bloodsend': 1493,
#  'ten': 7205,
#  'miracle': 4809,
#  'itplspls': 3990,
#  'lanre': 4281,
#  'fakeyes': 2917,
#  'eckankar': 2692,
#  'details': 2445,
#  'mail': 4604,
#  'box': 1551,
#  'nah': 5007,
#  'straight': 6945,
#  'bring': 1611,
#  'bud': 1649,
#  'drinks': 2623,
#  'thats': 7258,
#  'useful': 7680,
#  'hw': 3783,
#  'realy': 5999,
#  'mising': 4815,
#  'brother': 1628,
#  'scraped': 6354,
#  'barrel': 1322,
#  'shower': 6535,
#  'social': 6697,
#  'misfits': 4814,
#  'also': 1017,
#  'bringing': 1612,
#  'galileo': 3234,
#  'dobby': 2542,
#  'tmorrowpls': 7377,
#  'accomodate': 854,
#  'beautiful': 1367,
#  'truth': 7518,
#  'gravity': 3412,
#  'carefully': 1783,
#  'feels': 2974,
#  'light': 4377,
#  'heavy': 3572,
#  'leaves': 4326,
#  'birthdate': 1455,
#  'certificate': 1844,
#  'april': 1123,
#  'date': 2325,
#  'publish': 5872,
#  'shall': 6471,
#  'keep': 4150,
#  'difficulties': 2487,
#  'works': 8079,
#  'friend': 3174,
#  'request': 6114,
#  'mmmm': 4842,
#  'fair': 2914,
#  'weaknesses': 7890,
#  'grins': 3428,
#  'pushes': 5893,
#  'knees': 4214,
#  'exposes': 2887,
#  'belly': 1402,
#  'pulls': 5877,
#  'head': 3548,
#  'wicked': 7982,
#  'deal': 2352,
#  'gate': 3254,
#  'charles': 1866,
#  'last': 4289,
#  'uh': 7580,
#  'mind': 4789,
#  'horrible': 3707,
#  'gal': 3232,
#  'knew': 4215,
#  'going': 3348,
#  'wif': 7987,
#  'contacted': 2117,
#  'dating': 2328,
#  'entered': 2776,
#  'becausethey': 1371,
#  'fancy': 2933,
#  'landline': 4273,
#  '09058098002': 178,
#  'pobox1': 5641,
#  'w14rg': 7803,
#  '150p': 306,
#  'worry': 8088,
#  'though': 7312,
#  'understand': 7607,
#  'important': 3842,
#  'place': 5597,
#  'poorly': 5683,
#  'punishment': 5880,
#  'face': 2901,
#  'worst': 8093,
#  'ever': 2830,
#  'happened': 3518,
#  'brb': 1585,
#  'kill': 4179,
#  'nope': 5159,
#  'might': 4778,
#  'plz': 5636,
#  'note': 5172,
#  'anyone': 1081,
#  'co': 2002,
#  'asks': 1179,
#  'type': 7569,
#  'disconnect': 2518,
#  'callcoz': 1728,
#  'iz': 4003,
#  'terrorist': 7218,
#  'sim': 6571,
#  'card': 1774,
#  'itz': 3997,
#  'confirmd': 2097,
#  'motorola': 4917,
#  'verified': 7737,
#  'cnn': 2001,
#  'ibn': 3794,
#  'freemsg': 3154,
#  '86888': 754,
#  'reward': 6164,
#  'hours': 3720,
#  'subscribe6gbpmnth': 7001,
#  '3hrs': 507,
#  'stoptxtstop': 6937,
#  'press': 5770,
#  'conference': 2093,
#  'morning': 4905,
#  'feeling': 2972,
#  '750': 678,
#  'pound': 5712,
#  'easy': 2685,
#  '08712101358': 90,
#  '10p': 263,
#  'min': 4786,
#  'btnationalrate': 1644,
#  'angry': 1052,
#  'practice': 5730,
#  'difference': 2483,
#  'versus': 7741,
#  'hrs': 3736,
#  'natalja': 5028,
#  '25f': 405,
#  'inviting': 3942,
#  'yes440': 8230,
#  'no440': 5128,
#  'wwwsmsacunat27081980': 8162,
#  '62468': 634,
#  'vouchers': 7794,
#  'shop': 6514,
#  '85023': 744,
#  'savamob': 6322,
#  'offers': 5253,
#  'cs': 2240,
#  'pobox84': 5650,
#  'm263uz': 4565,
#  '300': 468,
#  'sub': 6993,
#  'knackered': 4213,
#  'full': 3208,
#  'lark': 4287,
#  'thanx': 7247,
#  'lions': 4405,
#  'england': 2765,
#  'lionm': 4403,
#  'mono': 4890,
#  'lionp': 4404,
#  'poly': 5669,
#  'wwwringtonescouk': 8156,
#  'original': 5354,
#  'best': 1416,
#  'tones': 7421,
#  '3gbp': 506,
#  'network': 5072,
#  'rates': 5964,
#  'apply': 1107,
#  'daal': 2283,
#  'finish': 3026,
#  'goodmorning': 3368,
#  'ga': 3227,
#  'guess': 3457,
#  'screwd': 6362,
#  'clearly': 1975,
#  'fault': 2953,
#  'aah': 817,
#  'lush': 4546,
#  'id': 3802,
#  'lots': 4489,
#  'soup': 6763,
#  'kind': 4185,
#  'fumbling': 3210,
#  'probably': 5809,
#  'closer': 1988,
#  'jay': 4032,
#  'tyler': 7567,
#  'two': 7557,
#  'trips': 7504,
#  'short': 6521,
#  'cute': 2273,
#  'sir': 6588,
#  'account': 859,
#  '1hr': 352,
#  'delay': 2402,
#  'carlos': 1793,
#  'minute': 4806,
#  'unless': 7629,
#  'sooner': 6735,
#  'entry': 2786,
#  '250': 402,
#  'word': 8067,
#  '80086': 702,
#  'tc': 7167,
#  'wwwtxttowincouk': 8172,
#  'ebay': 2690,
#  'less': 4346,
#  'elsewhere': 2737,
#  'indeed': 3869,
#  'hoping': 3703,
#  'rent': 6094,
#  'due': 2652,
#  'enough': 2774,
#  'reserves': 6124,
#  'completely': 2069,
#  'gone': 3355,
#  'loan': 4434,
#  'balance': 1295,
#  'mid': 4774,
#  'yep': 8226,
#  ...}

# %%
from itertools import islice
# Assuming `tfidf_vect.vocabulary_` is the dictionary you want to print
for key, value in islice(tfidf_vect.vocabulary_.items(), 10):
    print(key, value)
# Out:
# meet 4712
# lunch 4543
# la 4250
# lovely 4503
# smell 6658
# bus 1675
# aint 969
# tobacco 7385
# rose 6219
# redred 6038

# %%
# How are these vectors stored?
X_test_vect[0]
# Out:
# <1x8321 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2 stored elements in Compressed Sparse Row format>

# %%
# Can we convert the vectors to arrays?
X_test_vect[0].toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %% [markdown]
# ### Fit RandomForestClassifier On Top Of Vectors

# %%
# Fit a basic Random Forest model on these vectors
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf_model = rf.fit(X_train_vect, y_train.values.ravel())

# %%
# Use the trained model to make predictions on the test data
y_pred = rf_model.predict(X_test_vect)

# %%
y_train
# Out:
#       label
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 4452      0
# 4453      0
# 4454      1
# 4455      0
# 4456      0
#
# [4457 rows x 1 columns]

# %%
y_train.values.ravel()
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
# Evaluate the predictions of the model on the holdout test set
from sklearn.metrics import precision_score, recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
print('Precision: {} / Recall: {} / Accuracy: {}'.format(
    round(precision, 3), round(recall, 3), round((y_pred==y_test['label']).sum()/len(y_pred), 3)))
# Out:
# Precision: 1.0 / Recall: 0.76 / Accuracy: 0.968
